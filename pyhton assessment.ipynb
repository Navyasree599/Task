# %% [markdown]
# on conditional & control statements

# %%
x=int(input("enter a number"))
y=2*x+3
print("Predicted y:",y)
# Out:
# enter a number4
# Predicted y: 11

# %%
num1=int(input("enter temperature"))
if num1 > 30:
  print("hot")
else:
  print("normal")
# Out:
# enter temperature53
# hot

# %% [markdown]
# lists,sets

# %%
n=[19,9,13,11,24,18,22]
n.append(100)
print(n)
# Out:
# [19, 9, 13, 11, 24, 18, 22, 100]

# %%
n=['nani','navya','abhi','sree']
n.reverse()
print(n)
# Out:
# ['sree', 'abhi', 'navya', 'nani']

# %%
n=[5,10,19,13,9]
sum = 0
for i in n:
  sum=sum+i
print("sum", sum)
# Out:
# sum 56

# %%
n={'navya','nani','navya','abhi'}
n.remove('navya')
print(n)
# Out:
# {'nani', 'abhi'}

# %%
text=['t','a','a','s','s','k','k']
s=list(set(text))
print(s)
# Out:
# ['a', 't', 'k', 's']

# %%
n1={1,2,3,4}
n2={3,4,5,6}
res=n1.intersection(n2)
print(res)
# Out:
# {3, 4}

# %%
s=input("enter a string")
unique_chars = set(s)
print("Number of characters",unique_chars)
# Out:
# enter a stringnavyasri
# Number of characters {'r', 's', 'y', 'n', 'v', 'a', 'i'}
